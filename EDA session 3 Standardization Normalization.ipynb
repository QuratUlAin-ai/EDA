# %%
# gather sense of the data
# Pre-process the data
# data cleaning, and data wrangling
# addressing null values, outliers.
#graphicical representation for better visualization of the data

# %% [markdown]
# https://www.geeksforgeeks.org/normalization-vs-standardization/

# %% [markdown]
# ## Important EDA Concepts
# Exploratory Data Analysis (EDA) is a crucial step in data analysis and involves investigating datasets to summarize their main characteristics, often using visual methods. Here are some important EDA concepts:
#
# ### 1. Data Cleaning
# Missing Values: Identifying and handling missing values is essential. Techniques include removing rows/columns with missing values, or imputing missing values using statistical methods like mean, median, or mode.
# Outliers: Detecting and managing outliers, which can distort analysis results. Outliers can be visualized using boxplots and can be handled by removal, transformation, or capping.
# Data Types: Ensuring data types are correct (e.g., numeric, categorical). Incorrect data types can cause issues in analysis and modeling.
# ### 2. Summary Statistics
# Central Tendency: Measures such as mean, median, and mode describe the central point of the data.
# Dispersion: Measures such as range, variance, and standard deviation describe the spread of the data.
# Shape of Distribution: Skewness and kurtosis provide insights into the shape of the data distribution.
# ### 3. Data Visualization
# Histograms: Used to visualize the distribution of a single numerical variable.
# Boxplots: Useful for visualizing the distribution and identifying outliers for a numerical variable across different categories.
# Scatter Plots: Show the relationship between two numerical variables.
# Heatmaps: Visual representation of data where values are depicted by color. Commonly used to show correlations between variables.
# Pairplots: Multiple scatter plots arranged in a matrix to show relationships between multiple variables.
# ### 4. Correlation Analysis
# Correlation Coefficient: Measures the strength and direction of the linear relationship between two variables. Commonly used is Pearson's correlation coefficient.
# Correlation Matrix: A table showing correlation coefficients between variables. Useful for identifying relationships and multicollinearity.
# ### 5. Feature Engineering
# Creating New Features: Combining or transforming existing features to create new ones that might be more informative for analysis or modeling.
# Scaling and Normalization: Adjusting the range of the data. StandardScaler (z-score normalization) and MinMaxScaler (scaling to a range) are common techniques.
# ### 6. Bivariate Analysis
# Comparing Two Variables: Understanding relationships between two variables using scatter plots, box plots, and correlation coefficients.
# Categorical vs. Numerical: Analyzing how numerical variables differ across categories using visualizations like boxplots and bar charts.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

import seaborn as sns

import plotly.express as px
import plotly.figure_factory as ff

import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Dataset Files/modified_diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     2.288  33.0      1.0

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 773          4.0     83.0           86.0           19.0      0.0  29.3
# 774          0.0    134.0           58.0           20.0    291.0  26.4
# 775          8.0    125.0           96.0            0.0      0.0   0.0
# 776          1.0      NaN           50.0           16.0    375.0  25.9
# 777          0.0     94.0            0.0            0.0      0.0   0.0
#
#      DiabetesPedigreeFunction   Age  Outcome
# 773                     0.317  34.0      0.0
# 774                     0.352  21.0      0.0
# 775                     0.232  54.0      1.0
# 776                     0.655  24.0      0.0
# 777                     0.256  25.0      0.0

# %%
# Check the basic information of the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               736 non-null    float64
#  1   Glucose                   739 non-null    float64
#  2   BloodPressure             738 non-null    float64
#  3   SkinThickness             750 non-null    float64
#  4   Insulin                   737 non-null    float64
#  5   BMI                       740 non-null    float64
#  6   DiabetesPedigreeFunction  736 non-null    float64
#  7   Age                       739 non-null    float64
#  8   Outcome                   737 non-null    float64
# dtypes: float64(9)
# memory usage: 54.8 KB

# %%
# Get summary statistics
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   736.000000  739.000000     738.000000     750.000000  737.000000
# mean      3.838315  120.956698      69.066396      20.368000   79.876526
# std       3.389411   31.944621      19.070950      16.035276  114.911661
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  129.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  740.000000                736.000000  739.000000  737.000000
# mean    32.030946                  0.474351   33.098782    0.351425
# std      8.118442                  0.337002   11.713945    0.477740
# ...

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data["BMI"]
# Out:
# 0      33.6
# 1      26.6
# 2      23.3
# 3      28.1
# 4      43.1
#        ...
# 773    29.3
# 774    26.4
# 775     0.0
# 776    25.9
# 777     0.0
# Name: BMI, Length: 778, dtype: float64

# %%
data.columns.str.strip()
#The str.strip() function is used to remove leading and trailing characters.
#Strip whitespaces (including newlines)
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
s = pd.Series([' 1. Bat.  ', '2. Dog!\n', '3. fox?\t'])
s
#a set of specified characters from each string in the Series/Index from left and right sides.
# Out:
# 0     1. Bat.
# 1     2. Dog!\n
# 2     3. fox?\t
# dtype: object

# %%
s.str.strip('123.!? \n\t')
# Out:
# 0    Bat
# 1    Dog
# 2    fox
# dtype: object

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Pregnancies                 42
# Glucose                     39
# BloodPressure               40
# SkinThickness               28
# Insulin                     41
# BMI                         38
# DiabetesPedigreeFunction    42
# Age                         39
# Outcome                     41
# dtype: int64

# %%
# Replace zero values with NaN for specific columns
data[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = data[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, pd.NA)

# Check for missing values again
data.isnull().sum()
# Out:
# Pregnancies                  42
# Glucose                      44
# BloodPressure                72
# SkinThickness               255
# Insulin                     401
# BMI                          51
# DiabetesPedigreeFunction     42
# Age                          39
# Outcome                      41
# dtype: int64

# %%
# !pip install missingno

# %%
import missingno as msno
bar=msno.bar(data)
bar
# Out:
# <Axes: >

# %%
msno.heatmap(data)
# Out:
# <Axes: >

# %%
msno.matrix(data)
# Out:
# <Axes: >

# %%
x=data["Outcome"].mode()
x
# Out:
# 0    0.0
# Name: Outcome, dtype: float64

# %%
data['Outcome'] = data['Outcome'].fillna(x)

# %%
# Impute missing values with the mean
data.fillna(data.mean(), inplace=True)

# Verify that there are no missing values left
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data["Outcome"].unique()
# Out:
# array([1.        , 0.        , 0.35142469])

# %%
data["Outcome"] = data["Outcome"].replace(0.35142469, 0)

# %%
data["Outcome"].unique()
# Out:
# array([1.        , 0.        , 0.35142469])

# %%
data.duplicated().sum()
# Out:
# 4

# %%
# Keep the first occurrence of the duplicates
data = data.drop_duplicates(keep='first')

# Print the updated DataFrame
print(data)
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0            6.0  148.000000           72.0      35.000000  156.151194
# 1            1.0   85.000000           66.0      29.000000  156.151194
# 2            8.0  183.000000           64.0      29.208413  156.151194
# 3            1.0   89.000000           66.0      23.000000   94.000000
# 4            0.0  137.000000           40.0      35.000000  168.000000
# ..           ...         ...            ...            ...         ...
# 771          7.0  159.000000           66.0      29.208413  156.151194
# 772          0.0  137.000000           40.0      35.000000  168.000000
# 773          4.0   83.000000           86.0      19.000000  156.151194
# 775          8.0  125.000000           96.0      29.208413  156.151194
# 776          1.0  121.780654           50.0      16.000000  375.000000
#
#            BMI  DiabetesPedigreeFunction   Age   Outcome
# 0    33.600000                     0.627  50.0  1.000000
# ...

# %%
data[data['Pregnancies']>10]
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 24          11.0  143.000000      94.000000      33.000000  146.000000  36.6
# 28          13.0  145.000000      82.000000      19.000000  110.000000  22.2
# 36          11.0  138.000000      76.000000      29.208413  156.151194  33.2
# 72          13.0  126.000000      90.000000      29.208413  156.151194  43.4
# 86          13.0  106.000000      72.000000      54.000000  156.151194  36.6
# 88          15.0  136.000000      70.000000      29.208413  110.000000  37.1
# 159         17.0  163.000000      72.000000      41.000000  156.151194  40.9
# 193         11.0  135.000000      72.196884      29.208413  156.151194  52.3
# 215         12.0  151.000000      70.000000      29.208413  271.000000  41.8
# 254         12.0   92.000000      62.000000       7.000000  258.000000  27.6
# 259         11.0  155.000000      76.000000      28.000000  150.000000  33.3
# ...

# %%
#age > 30 and glucise is greater than 150
#The | operator is used for element-wise logical OR between the two Boolean Series.
#The result is a Boolean Series where each value is True if either the 'Age' is greater than 30 or the 'Glucose' level is greater than 150 (or both), and False otherwise.
data[(data["Age"]>30) | (data["Glucose"]>150)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin  \
# 0            6.0    148.0           72.0      35.000000  156.151194
# 1            1.0     85.0           66.0      29.000000  156.151194
# 2            8.0    183.0           64.0      29.208413  156.151194
# 4            0.0    137.0           40.0      35.000000  168.000000
# 8            2.0    197.0           70.0      45.000000  156.151194
# ..           ...      ...            ...            ...         ...
# 766          1.0    126.0           60.0      29.208413  156.151194
# 771          7.0    159.0           66.0      29.208413  156.151194
# 772          0.0    137.0           40.0      35.000000  168.000000
# 773          4.0     83.0           86.0      19.000000  156.151194
# 775          8.0    125.0           96.0      29.208413  156.151194
#
#            BMI  DiabetesPedigreeFunction   Age   Outcome
# 0    33.600000                     0.627  50.0  1.000000
# ...

# %%
data.shape
# Out:
# (774, 9)

# %%
data["BloodPressure"].nunique()
# Out:
# 47

# %%
data["BloodPressure"].unique()
# Out:
# array([ 72.        ,  66.        ,  64.        ,  40.        ,
#         74.        ,  50.        ,  72.19688385,  70.        ,
#         92.        ,  80.        ,  60.        ,  84.        ,
#         30.        ,  88.        ,  90.        ,  94.        ,
#         76.        ,  82.        ,  75.        ,  58.        ,
#         78.        ,  68.        , 110.        ,  56.        ,
#         62.        ,  86.        ,  48.        ,  44.        ,
#         65.        , 108.        ,  55.        ,  96.        ,
#        122.        ,  85.        ,  54.        ,  52.        ,
#         98.        , 104.        ,  95.        ,  46.        ,
#        102.        , 100.        ,  61.        ,  24.        ,
#         38.        , 106.        , 114.        ])

# %%
data.groupby(['BloodPressure']).mean()
# Out:
#                Pregnancies     Glucose  SkinThickness     Insulin        BMI  \
# BloodPressure
# 24.000000         1.000000   89.000000      19.000000   25.000000  27.800000
# 30.000000         1.000000  103.000000      29.208413  156.151194  43.300000
# 38.000000         1.000000  109.000000      18.000000  120.000000  32.603714
# 40.000000         0.000000  137.000000      35.000000  168.000000  37.851857
# 44.000000         3.250000  110.500000      25.000000  110.787798  28.175000
# 46.000000         1.500000  133.000000      20.000000  209.000000  31.550000
# 48.000000         2.000000  104.356131      28.841683  149.460477  33.860743
# 50.000000         2.000000  119.060050      24.416679  174.596613  28.531055
# 52.000000         1.983832  113.078065      25.483365  162.875597  31.170000
# 54.000000         2.727273  116.252787      24.329567  119.404871  29.073740
# 55.000000         4.500000   82.500000      24.604207  156.151194  28.501857
# ...

# %%
# Group by Outcome and Age, then calculate the mean for each combination
grouped_mean_age = data.groupby(['Outcome', 'Age']).mean()
grouped_mean_age
# Out:
#               Pregnancies     Glucose  BloodPressure  SkinThickness  \
# Outcome Age
# 0.0     21.0     1.287777  109.363947      66.807477      24.794136
#         22.0     1.629307  106.409131      65.120343      23.955987
#         23.0     1.602947  107.389331      70.868871      27.639432
#         24.0     2.185462  113.503406      66.466320      28.868069
#         25.0     1.828278   96.605828      65.638308      28.415346
# ...                   ...         ...            ...            ...
# 1.0     60.0     6.000000  157.500000      70.000000      32.604207
#         61.0     4.000000  146.000000      92.000000      29.208413
#         62.0     1.000000  151.000000      77.000000      64.104207
#         66.0     4.000000  174.000000      91.000000      29.208413
#         67.0     4.000000  146.000000      78.000000      29.208413
#
#                  Insulin        BMI  DiabetesPedigreeFunction
# Outcome Age
# ...

# %%
data[(data["Age"]==22) | (data["Outcome"]==0)]
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 1            1.0   85.000000      66.000000      29.000000  156.151194  26.6
# 3            1.0   89.000000      66.000000      23.000000   94.000000  28.1
# 5            5.0  116.000000      74.000000      29.208413  156.151194  25.6
# 7           10.0  121.780654      72.196884      29.208413  156.151194  35.3
# 10           4.0  110.000000      92.000000      29.208413  156.151194  37.6
# ..           ...         ...            ...            ...         ...   ...
# 765          5.0  121.000000      72.000000      23.000000  112.000000  26.2
# 767          1.0   93.000000      70.000000      31.000000  156.151194  30.4
# 768          0.0  102.000000      64.000000      46.000000   78.000000  40.6
# 773          4.0   83.000000      86.000000      19.000000  156.151194  29.3
# 776          1.0  121.780654      50.000000      16.000000  375.000000  25.9
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %%
grouped_mean_age = data.groupby(['Outcome', 'Age']).mean().unstack(level=0)
# Plotting the mean values by Age and Outcome
grouped_mean_age.plot(kind='bar', figsize=(20, 10))
plt.title('Mean Values by Age and Outcome')
plt.ylabel('Mean')
plt.xlabel('Age')
plt.xticks(rotation=90)
plt.legend(title='Outcome', loc='best')
plt.grid(True)
plt.show()

# %%
data.groupby(['Outcome']).mean()
# Out:
#           Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0.000000     3.363101  111.382398      70.922639      28.081340  141.823124
# 0.351425     3.605813  116.997641      69.204726      26.519330  165.687197
# 1.000000     4.801931  141.731808      75.082680      31.631813  181.233792
#
#                 BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0.000000  31.299424                  0.425842  31.494062
# 0.351425  30.414996                  0.477782  30.985247
# 1.000000  35.368002                  0.561905  36.499140

# %%
data.groupby(['Glucose'])["BMI"].mean()
# Out:
# Glucose
# 44.0     25.000000
# 57.0     27.250000
# 61.0     34.400000
# 65.0     32.000000
# 67.0     45.300000
#            ...
# 195.0    28.000000
# 196.0    37.933333
# 197.0    31.950000
# 198.0    41.300000
# 199.0    42.900000
# Name: BMI, Length: 134, dtype: float64

# %%
import matplotlib.pyplot as plt

# Plot histograms
#This method is called on the DataFrame data. It generates histograms for all numeric columns in the DataFrame. Each histogram represents the distribution of data within that specific column.
#bins=20: The bins parameter specifies the number of bins or intervals into which the data is divided on the x-axis for each histogram. In this case, the
#data in each column will be divided into 20 bins. More bins result in a more detailed histogram, while fewer bins make the histogram more general.
data.hist(bins=20, figsize=(14, 10))
plt.show()

# %% [markdown]
# ## Boxplot
# Another way to visualize the distribution of a variable is a boxplot.
# ![image.png](attachment:image.png)

# %%
dften=sns.boxplot(data['Insulin'])
dften
# Out:
# <Axes: ylabel='Insulin'>

# %% [markdown]
# ## correlation matrix
# The first thing I like to do when analyzing my variables is visualizing it through a correlation matrix because it’s the fastest way to develop a general understanding of all of my variables. To review, correlation is a measurement that describes the relationship between two variables — if you want to learn more about it, you can check out my statistics cheat sheet here.) Thus, a correlation matrix is a table that shows the correlation coefficients between many variables. I used sns.heatmap() to plot a correlation matrix of all of the variables
#
# https://terenceshin.medium.com/week-2-52-stats-cheat-sheet-ae38a2e5cdc6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import seaborn as sns

# Compute correlation matrix
corr_matrix = data.corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
# Create pairplot
#This function generates a matrix of scatter plots (pairwise plots) for each pair of numerical columns in the DataFrame data.
#Along the diagonal, it plots the distribution of each variable.
# means that a Kernel Density Estimate (KDE) plot will be used on the diagonal. A KDE plot is a smoothed version of a histogram that estimates the probability density function of the variable.
sns.pairplot(data, hue='Outcome', diag_kind='kde')
plt.show()

# %%
# Create a new feature: Age_BMI
data['Age_BMI'] = data['Age'] * data['BMI']
data['Age_BMI']
# Out:
# 0      1680.000000
# 1       824.600000
# 2       745.600000
# 3       590.100000
# 4      1422.300000
#           ...
# 771    1094.400000
# 772    1075.922558
# 773     996.200000
# 775    1760.600550
# 776     621.600000
# Name: Age_BMI, Length: 774, dtype: float64

# %%
data['BMI groups']=pd.qcut(data["BMI"],q=4)
print(data['BMI groups'])
data
# Out:
# 0                  (32.604, 36.5]
# 1      (18.198999999999998, 27.8]
# 2      (18.198999999999998, 27.8]
# 3                  (27.8, 32.604]
# 4                    (36.5, 67.1]
#                   ...
# 771                (27.8, 32.604]
# 772                (27.8, 32.604]
# 773                (27.8, 32.604]
# 775                (27.8, 32.604]
# 776    (18.198999999999998, 27.8]
# Name: BMI groups, Length: 774, dtype: category
# Categories (4, interval[float64, right]): [(18.198999999999998, 27.8] < (27.8, 32.604] < (32.604, 36.5] <
#                                            (36.5, 67.1]]
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0            6.0  148.000000           72.0      35.000000  156.151194
# 1            1.0   85.000000           66.0      29.000000  156.151194
# 2            8.0  183.000000           64.0      29.208413  156.151194
# 3            1.0   89.000000           66.0      23.000000   94.000000
# ...

# %%
print(data['Insulin'].max())
print(data['Insulin'].min())
# Out:
# 846.0
# 14.0

# %%
plt.hist(data['Insulin'])
plt.show()

# %%
data['Insulin range'] = pd.cut(data['Insulin'], bins=[0,250,500,750,1000],labels=['copper','silver', 'gold', 'platinum'])
data['Insulin range']
# Out:
# 0      copper
# 1      copper
# 2      copper
# 3      copper
# 4      copper
#         ...
# 771    copper
# 772    copper
# 773    copper
# 775    copper
# 776    silver
# Name: Insulin range, Length: 774, dtype: category
# Categories (4, object): ['copper' < 'silver' < 'gold' < 'platinum']

# %%
data[data['Insulin range']=='platinum']
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 13          1.0    189.0           60.0           23.0    846.0  30.1
#
#     DiabetesPedigreeFunction   Age  Outcome  Age_BMI      BMI groups  \
# 13                     0.398  59.0      1.0   1775.9  (27.8, 32.604]
#
#    Insulin range
# 13      platinum

# %%
data[["SkinThickness","BMI"]][data['Insulin range']=='gold']
# Out:
#      SkinThickness   BMI
# 228      39.000000  36.7
# 247      29.208413  52.3
# 286      44.000000  38.7
# 409      49.000000  42.4
# 584      24.000000  28.7
# 655      27.000000  38.7
# 753      44.000000  43.3

# %%
data
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0            6.0  148.000000           72.0      35.000000  156.151194
# 1            1.0   85.000000           66.0      29.000000  156.151194
# 2            8.0  183.000000           64.0      29.208413  156.151194
# 3            1.0   89.000000           66.0      23.000000   94.000000
# 4            0.0  137.000000           40.0      35.000000  168.000000
# ..           ...         ...            ...            ...         ...
# 771          7.0  159.000000           66.0      29.208413  156.151194
# 772          0.0  137.000000           40.0      35.000000  168.000000
# 773          4.0   83.000000           86.0      19.000000  156.151194
# 775          8.0  125.000000           96.0      29.208413  156.151194
# 776          1.0  121.780654           50.0      16.000000  375.000000
#
#            BMI  DiabetesPedigreeFunction   Age   Outcome      Age_BMI  \
# ...

# %%
data["Glucose"].mean()
# Out:
# 121.79631624527386

# %%
#This method computes the standard deviation of the values in the Series (i.e., the Glucose column).
#By default, it calculates the sample standard deviation, which means it divides by n-1 (where n is the number of observations) to correct
# for bias in the estimation of the population standard deviation.
data["Glucose"].std()
# Out:
# 29.626393034745515

# %%
print(data.dtypes)
# Out:
# Pregnancies                  float64
# Glucose                      float64
# BloodPressure                float64
# SkinThickness                float64
# Insulin                      float64
# BMI                          float64
# DiabetesPedigreeFunction     float64
# Age                          float64
# Outcome                      float64
# Age_BMI                      float64
# BMI groups                  category
# Insulin range               category
# dtype: object

# %% [markdown]
# Scale the features
# data.drop('Outcome', axis=1) removes the Outcome column from the DataFrame because Outcome is typically a target variable in a classification problem and should not be scaled like the features.
#
# scaler.fit_transform() first fits the scaler to the data (calculating the mean and standard deviation for each feature) and then transforms the data by applying the standardization (scaling).
#
# The result, scaled_data, is a NumPy array containing the standardized features.
#
# Convert scaled data back to DataFrame
# The scaled data is converted back into a Pandas DataFrame for easier manipulation and analysis.
#
# columns=data.columns[:-1] ensures that the columns in the new DataFrame have the same names as the original columns (excluding the Outcome column).
#
# After scaling, the Outcome column is added back to the DataFrame, so the resulting scaled_df includes both the scaled features and the original target variable.

# %%
from sklearn.preprocessing import StandardScaler


scaler = StandardScaler()
scaled_data = scaler.fit_transform(data.drop('Outcome', axis=1))

scaled_df = pd.DataFrame(scaled_data, columns=data.columns[:-1])

scaled_df['Outcome'] = data['Outcome']


scaled_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-49c7fb3782ad> in <cell line: 5>()
#       3
#       4 scaler = StandardScaler()
# ----> 5 scaled_data = scaler.fit_transform(data.drop('Outcome', axis=1))
#       6
#       7 scaled_df = pd.DataFrame(scaled_data, columns=data.columns[:-1])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     914         if y is None:
# ...

# %% [markdown]
# StandardScaler standardizes features by removing the mean and scaling to unit variance.
#
# MinMaxScaler normalizes features by scaling each feature to a given range (usually [0, 1]).
#
# The features variable contains all the input features (i.e., all columns except Outcome), and target holds the Outcome column, which is typically the target variable in a classification problem.
#
# Standardization
# StandardScaler: This scaler is used to standardize the features, which involves subtracting the mean and scaling to unit variance (z-score normalization). This transforms the data so that each feature has a mean of 0 and a standard deviation of 1.
#
# fit_transform: The scaler first calculates the mean and standard deviation of each feature (fit) and then applies the transformation to standardize the data (transform).
#
# The result is stored in standardized_features, which is then converted back into a DataFrame standardized_df with the same column names as the original features.
#
# Normalization
# MinMaxScaler: This scaler normalizes the features by scaling them to a range of [0, 1] (or another specified range). The minimum value of each feature becomes 0, and the maximum value becomes 1.
#
# fit_transform: The scaler first finds the minimum and maximum values of each feature (fit) and then applies the transformation to scale the data into the [0, 1] range (transform).
#
# The result is stored in normalized_features, which is then converted back into a DataFrame normalized_df with the same column names as the original features.

# %% [markdown]
# https://www.geeksforgeeks.org/normalization-vs-standardization/

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Separating features and target
features = data.drop('Outcome', axis=1)
target = data['Outcome']

# Standardization- to a bell curve/z score normalisation
scaler_standard = StandardScaler()
standardized_features = scaler_standard.fit_transform(features)
standardized_df = pd.DataFrame(standardized_features, columns=features.columns)

# Normalization- scale same
scaler_minmax = MinMaxScaler()
normalized_features = scaler_minmax.fit_transform(standardized_df)
normalized_df = pd.DataFrame(normalized_features, columns=features.columns)

# Displaying the first few rows of the standardized and normalized data
standardized_df.head(), normalized_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-9af56f9857da> in <cell line: 9>()
#       7 # Standardization- to a bell curve/z score normalisation
#       8 scaler_standard = StandardScaler()
# ----> 9 standardized_features = scaler_standard.fit_transform(features)
#      10 standardized_df = pd.DataFrame(standardized_features, columns=features.columns)
#      11
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
# ...

# %%
import matplotlib.pyplot as plt

# Plot histograms
standardized_df["Age"].hist(bins=20, figsize=(14, 10))
plt.show()
